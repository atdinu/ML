# %%
import pandas as pd
import numpy as np
import re

# %%
Tita_in=pd.read_csv("train.csv")

# %%
Tita_in.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Tita_in.drop(['Embarked'],axis=1,inplace=True)
Tita_in.drop(['Cabin'],axis=1,inplace=True)
Tita_in.drop(['Name'],axis=1,inplace=True)
Tita_in.drop(['Ticket'],axis=1,inplace=True)

# %%
Tita_in['Sex'] = Tita_in['Sex'].map({'male': 1, 'female': 0})

# %%
Tita_in_missing=Tita_in[np.isnan(Tita_in['Age'])]

# %%
Tita_in_missing
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
Male=[]
MaleAge=[]
Female=[]
FemaleAge=[]
Girl=[]
GirlAge=[]
Boy=[]
NoyAge=[]
for name,age in Tita_in[['Name','Age']:
    #print(name)
    #name_ar=re.split(r'\s',name)
    name_ar=name.split()
    #print(name_ar)
    for name_mr in name_ar:
        if(name_mr=='Mr.'):
            Male.append(name)
        if(name_mr=='Mrs.'):
            Female.append(name)
        if(name_mr=='Miss.'):
            Girl.append(name)
        if(name_mr=='Master.'):
            Boy.append(name)
# Out:
#   File "<ipython-input-83-b70285813c23>", line 12
#     name_ar=name.split()
#            ^
# SyntaxError: invalid syntax

# %%
Male_pd=pd.Series(Male)
df=Male_pd.to_frame()

# %%
df1=df.rename(columns={0: "Male_Names"})

# %%
df1
# Out:
#                                Male_Names
# 0                 Braund, Mr. Owen Harris
# 1                Allen, Mr. William Henry
# 2                        Moran, Mr. James
# 3                 McCarthy, Mr. Timothy J
# 4          Saundercock, Mr. William Henry
# 5             Andersson, Mr. Anders Johan
# 6            Williams, Mr. Charles Eugene
# 7                    Fynney, Mr. Joseph J
# 8                   Beesley, Mr. Lawrence
# 9            Sloper, Mr. William Thompson
# 10                Emir, Mr. Farred Chehab
# 11         Fortune, Mr. Charles Alexander
# 12                    Todoroff, Mr. Lalio
# 13                  Wheadon, Mr. Edward H
# 14                Meyer, Mr. Edgar Joseph
# 15         Holverson, Mr. Alexander Oskar
# 16                       Mamee, Mr. Hanna
# 17               Cann, Mr. Ernest Charles
# 18                    Kraeff, Mr. Theodor
# 19               Rogers, Mr. William John
# 20                      Lennon, Mr. Denis
# ...

# %%
for male in df1['Male_Names']:
    df1['Age']=100

# %%
for maleg in Male_pd:
    for name in Tita_in['Name']:
        if(name==maleg):
            Male_pd['Age']=20
