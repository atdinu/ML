# %%
import numpy as np
import pandas as pd

# %%
ho_Data=pd.read_csv('train.csv')

# %%
ho_Data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
ho_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
ho_Data_up=ho_Data.copy()

# %%
ho_Data_up.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
ho_Data_up.drop(['GarageYrBlt'],axis=1,inplace=True)
ho_Data_up.drop(['LotFrontage'],axis=1,inplace=True)

# %%
ho_Data_categorical = ho_Data_up.select_dtypes(include=['object'])
ho_Data_noncategorical = ho_Data_up.select_dtypes(exclude=['object'])
ho_Data_categorical=ho_Data_categorical.fillna('NoVal')

# %%
ho_Data_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 43 columns):
# MSZoning         1460 non-null object
# Street           1460 non-null object
# Alley            1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1460 non-null object
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1460 non-null object
# ...

# %%
ho_Data_noncategorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 36 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# MasVnrArea       1452 non-null float64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
ho_Data_categorical = ho_Data_categorical.apply(le.fit_transform)
ho_Data_categorical.head()
# Out:
#    MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0         3       1      1         3            3          0          4
# 1         3       1      1         3            3          0          2
# 2         3       1      1         0            3          0          4
# 3         3       1      1         0            3          0          0
# 4         3       1      1         0            3          0          2
#
#    LandSlope  Neighborhood  Condition1  ...  GarageType  GarageFinish  \
# 0          0             5           2  ...           1             2
# 1          0            24           1  ...           1             2
# 2          0             5           2  ...           1             2
# 3          0             6           2  ...           5             3
# 4          0            15           2  ...           1             2
#
#    GarageQual  GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  SaleType  \
# ...

# %%
ho_Data_up = ho_Data_up.drop(ho_Data_categorical.columns, axis=1)
ho_Data_up = pd.concat([ho_Data_up, ho_Data_categorical], axis=1)
ho_Data_up.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageType  GarageFinish  \
# 0       196.0         706           0  ...           1             2
# 1         0.0         978           0  ...           1             2
# 2       162.0         486           0  ...           1             2
# 3         0.0         216           0  ...           5             3
# 4       350.0         655           0  ...           1             2
#
#    GarageQual  GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  SaleType  \
# ...

# %%
ho_Data_noncategorical.quantile([.1, .25, .5, .75, .98, 1], axis = 0)
# Out:
#            Id  MSSubClass    LotArea  OverallQual  OverallCond  YearBuilt  \
# 0.10   146.90        20.0    5000.00          5.0          5.0     1924.9
# 0.25   365.75        20.0    7553.50          5.0          5.0     1954.0
# 0.50   730.50        50.0    9478.50          6.0          5.0     1973.0
# 0.75  1095.25        70.0   11601.50          7.0          6.0     2000.0
# 0.98  1430.82       188.2   25251.62          9.0          8.0     2008.0
# 1.00  1460.00       190.0  215245.00         10.0          9.0     2010.0
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0.10        1950.0        0.00        0.00        0.00  ...         0.0
# 0.25        1967.0        0.00        0.00        0.00  ...         0.0
# 0.50        1994.0        0.00      383.50        0.00  ...         0.0
# 0.75        2004.0      166.00      712.25        0.00  ...       168.0
# 0.98        2008.0      650.98     1442.64      658.12  ...       430.1
# ...

# %%
ho_Data_noncategorical.to_csv('ho_Data_noncategorical.csv')

# %%
ho_Data_noncategorical.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
ho_Data_noncategorical_perc=ho_Data_noncategorical[['LotArea', 'MasVnrArea', 'BsmtFinSF1','BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GarageArea']]

# %%
ho_Data_noncategorical_perc.quantile([.1, .25, .5, .75, .98, 1], axis = 0)
# Out:
#         LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0.10    5000.00        0.00        0.00       74.9       636.90    756.90
# 0.25    7553.50        0.00        0.00      223.0       795.75    882.00
# 0.50    9478.50        0.00      383.50      477.5       991.50   1087.00
# 0.75   11601.50      166.00      712.25      808.0      1298.25   1391.25
# 0.98   25251.62      650.98     1442.64     1678.2      2001.64   2072.28
# 1.00  215245.00     1600.00     5644.00     2336.0      6110.00   4692.00
#
#       2ndFlrSF  GarageArea
# 0.10      0.00      240.00
# 0.25      0.00      334.50
# 0.50      0.00      480.00
# 0.75    728.00      576.00
# 0.98   1318.56      907.46
# 1.00   2065.00     1418.00

# %%
quant_df = ho_Data_noncategorical_perc.quantile([.01,1])
quant_df
# Out:
#        LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0.01    1680.0         0.0         0.0        0.0          0.0     520.0
# 1.00  215245.0      1600.0      5644.0     2336.0       6110.0    4692.0
#
#       2ndFlrSF  GarageArea
# 0.01       0.0         0.0
# 1.00    2065.0      1418.0

# %%
ho_Data_noncategorical_perc = ho_Data_noncategorical_perc.apply(lambda x: x[(x < quant_df.loc[1,x.name])], axis=0)

# %%
ho_Data_noncategorical_perc
# Out:
#       LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0      8450.0       196.0       706.0      150.0        856.0     856.0
# 1      9600.0         0.0       978.0      284.0       1262.0    1262.0
# 2     11250.0       162.0       486.0      434.0        920.0     920.0
# 3      9550.0         0.0       216.0      540.0        756.0     961.0
# 4     14260.0       350.0       655.0      490.0       1145.0    1145.0
# 5     14115.0         0.0       732.0       64.0        796.0     796.0
# 6     10084.0       186.0      1369.0      317.0       1686.0    1694.0
# 7     10382.0       240.0       859.0      216.0       1107.0    1107.0
# 8      6120.0         0.0         0.0      952.0        952.0    1022.0
# 9      7420.0         0.0       851.0      140.0        991.0    1077.0
# 10    11200.0         0.0       906.0      134.0       1040.0    1040.0
# 11    11924.0       286.0       998.0      177.0       1175.0    1182.0
# ...

# %%
pd.isnull(ho_Data_noncategorical_perc).sum()
# Out:
# LotArea        1
# MasVnrArea     9
# BsmtFinSF1     1
# BsmtUnfSF      1
# TotalBsmtSF    1
# 1stFlrSF       1
# 2ndFlrSF       1
# GarageArea     1
# dtype: int64

# %%
ho_Data_noncategorical = ho_Data_noncategorical.drop(ho_Data_noncategorical_perc.columns, axis=1)
ho_Data_noncategorical = pd.concat([ho_Data_noncategorical, ho_Data_noncategorical_perc], axis=1)
ho_Data_noncategorical.head()
# Out:
#    Id  MSSubClass  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60            7            5       2003          2003
# 1   2          20            6            8       1976          1976
# 2   3          60            7            5       2001          2002
# 3   4          70            7            5       1915          1970
# 4   5          60            8            5       2000          2000
#
#    BsmtFinSF2  LowQualFinSF  GrLivArea  BsmtFullBath  ...  YrSold  SalePrice  \
# 0           0             0       1710             1  ...    2008     208500
# 1           0             0       1262             0  ...    2007     181500
# 2           0             0       1786             1  ...    2008     223500
# 3           0             0       1717             1  ...    2006     140000
# 4           0             0       2198             1  ...    2008     250000
#
#    LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# ...

# %%
pd.isnull(ho_Data_noncategorical).sum()
# Out:
# Id               0
# MSSubClass       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF2       0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# LotArea          1
# MasVnrArea       9
# BsmtFinSF1       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# 1stFlrSF         1
# 2ndFlrSF         1
# GarageArea       1
# dtype: int64

# %%
ho_Data_up = ho_Data_up.drop(ho_Data_noncategorical.columns, axis=1)
ho_Data_up = pd.concat([ho_Data_up, ho_Data_noncategorical], axis=1)
ho_Data_up.head()
# Out:
#    MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0         3       1      1         3            3          0          4
# 1         3       1      1         3            3          0          2
# 2         3       1      1         0            3          0          4
# 3         3       1      1         0            3          0          0
# 4         3       1      1         0            3          0          2
#
#    LandSlope  Neighborhood  Condition1  ...  YrSold  SalePrice  LotArea  \
# 0          0             5           2  ...    2008     208500   8450.0
# 1          0            24           1  ...    2007     181500   9600.0
# 2          0             5           2  ...    2008     223500  11250.0
# 3          0             6           2  ...    2006     140000   9550.0
# 4          0            15           2  ...    2008     250000  14260.0
#
#    MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# ...

# %%
ho_Data_up.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
# MSZoning         1460 non-null int32
# Street           1460 non-null int32
# Alley            1460 non-null int32
# LotShape         1460 non-null int32
# LandContour      1460 non-null int32
# Utilities        1460 non-null int32
# LotConfig        1460 non-null int32
# LandSlope        1460 non-null int32
# Neighborhood     1460 non-null int32
# Condition1       1460 non-null int32
# Condition2       1460 non-null int32
# BldgType         1460 non-null int32
# HouseStyle       1460 non-null int32
# RoofStyle        1460 non-null int32
# RoofMatl         1460 non-null int32
# Exterior1st      1460 non-null int32
# Exterior2nd      1460 non-null int32
# MasVnrType       1460 non-null int32
# ExterQual        1460 non-null int32
# ExterCond        1460 non-null int32
# Foundation       1460 non-null int32
# BsmtQual         1460 non-null int32
# ...

# %%
ho_Data_up.quantile([.1, .25, .5, .75, .98, 1], axis = 0)
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0.10       3.0     1.0    1.0       0.0          2.0        0.0        0.0
# 0.25       3.0     1.0    1.0       0.0          3.0        0.0        2.0
# 0.50       3.0     1.0    1.0       3.0          3.0        0.0        4.0
# 0.75       3.0     1.0    1.0       3.0          3.0        0.0        4.0
# 0.98       4.0     1.0    2.0       3.0          3.0        0.0        4.0
# 1.00       4.0     1.0    2.0       3.0          3.0        1.0        4.0
#
#       LandSlope  Neighborhood  Condition1  ...  YrSold  SalePrice   LotArea  \
# 0.10        0.0           5.0         2.0  ...  2006.0  106475.00    5000.0
# 0.25        0.0           7.0         2.0  ...  2007.0  129975.00    7549.0
# 0.50        0.0          12.0         2.0  ...  2008.0  163000.00    9477.0
# 0.75        0.0          17.0         2.0  ...  2009.0  214000.00   11600.0
# ...

# %%
ho_Data_up.dropna(inplace=True)

# %%
ho_Data_up.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1447 entries, 0 to 1459
# Data columns (total 79 columns):
# MSZoning         1447 non-null int32
# Street           1447 non-null int32
# Alley            1447 non-null int32
# LotShape         1447 non-null int32
# LandContour      1447 non-null int32
# Utilities        1447 non-null int32
# LotConfig        1447 non-null int32
# LandSlope        1447 non-null int32
# Neighborhood     1447 non-null int32
# Condition1       1447 non-null int32
# Condition2       1447 non-null int32
# BldgType         1447 non-null int32
# HouseStyle       1447 non-null int32
# RoofStyle        1447 non-null int32
# RoofMatl         1447 non-null int32
# Exterior1st      1447 non-null int32
# Exterior2nd      1447 non-null int32
# MasVnrType       1447 non-null int32
# ExterQual        1447 non-null int32
# ExterCond        1447 non-null int32
# Foundation       1447 non-null int32
# BsmtQual         1447 non-null int32
# ...

# %%
Y=ho_Data_up['SalePrice']

# %%
X=ho_Data_up.drop(['SalePrice'],axis=1)
X=X.drop(['Id'],axis=1)

# %%
#defining a normalisation function 
def normalize (x): 
    return ( (x-np.mean(x))/ (max(x) - min(x)))

# %%
pd.isnull(X).sum()
# Out:
# MSZoning         0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
#                 ..
# YearRemodAdd     0
# BsmtFinSF2       0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# ...

# %%
X.to_csv('checkNan.csv')

# %%
#St_X=(X-X.mean())/X.std()
St_X = X.apply(normalize)

# %%
import statsmodels.api as sm
X_train_sm = St_X
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(Y,X_train_sm).fit()
print(type(lm_1))
# print the coefficients
lm_1.params
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
# const            179922.475466
# MSZoning          -2828.874570
# Street            35337.255459
# Alley              4923.582588
# LotShape          -1149.186975
# LandContour        2362.461012
# Utilities        -50090.141436
# LotConfig          -608.251435
# LandSlope          1532.422446
# Neighborhood       4905.939088
# Condition1       -10869.483847
# Condition2       -78839.412108
# BldgType          -7237.815345
# HouseStyle         -497.185585
# RoofStyle          6063.837877
# RoofMatl          15387.907171
# Exterior1st      -17968.493423
# Exterior2nd       12011.356401
# MasVnrType        15230.674715
# ExterQual        -30416.826584
# ExterCond          1888.344308
# Foundation        11937.228753
# BsmtQual         -14119.501059
# BsmtCond           3999.635919
# BsmtExposure      -7520.776661
# BsmtFinType1        822.560755
# BsmtFinType2      -2412.221046
# Heating           -7830.778043
# ...

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     137.5
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        11:34:01   Log-Likelihood:                -16796.
# No. Observations:                1447   AIC:                         3.374e+04
# Df Residuals:                    1371   BIC:                         3.414e+04
# Df Model:                          75
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.799e+05    718.153    250.535      0.000    1.79e+05    1.81e+05
# ...

# %%
St_X1=St_X.drop(['HouseStyle','LowQualFinSF','HalfBath','LandSlope','LotConfig','BsmtFinType1','CentralAir','BsmtHalfBath'],axis=1)

# %%
X_train_sm = St_X1
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(Y,X_train_sm).fit()
print(type(lm_1))
# print the coefficients
lm_1.params
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
# const            179922.475466
# MSZoning          -3030.565949
# Street            34816.022842
# Alley              4911.762525
# LotShape          -1265.116412
# LandContour        2096.850189
# Utilities        -49765.240359
# Neighborhood       4798.511983
# Condition1       -11066.945306
# Condition2       -78804.019911
# BldgType          -7098.058645
# RoofStyle          6121.426682
# RoofMatl          15799.793312
# Exterior1st      -17863.587792
# Exterior2nd       11958.860555
# MasVnrType        15266.437410
# ExterQual        -30464.028728
# ExterCond          1815.473813
# Foundation        11902.648988
# BsmtQual         -14306.880245
# BsmtCond           3892.070462
# BsmtExposure      -7521.853757
# BsmtFinType2      -2312.260960
# Heating           -6419.700144
# HeatingQC         -2738.294983
# Electrical        -2249.472816
# KitchenQual      -20980.501934
# Functional        24055.904400
# ...

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     152.4
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        11:37:46   Log-Likelihood:                -16796.
# No. Observations:                1447   AIC:                         3.373e+04
# Df Residuals:                    1378   BIC:                         3.409e+04
# Df Model:                          68
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.799e+05    716.447    251.132      0.000    1.79e+05    1.81e+05
# ...

# %%
St_X2=St_X1.drop(['MiscVal','ExterCond','BsmtFinType2','Heating','FullBath'],axis=1)

# %%
X_train_sm = St_X2
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(Y,X_train_sm).fit()
print(type(lm_1))
# print the coefficients
lm_1.params
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
# const            179922.475466
# MSZoning          -3331.720173
# Street            34805.223086
# Alley              4870.988964
# LotShape          -1256.393449
# LandContour        2101.086729
# Utilities        -49879.600687
# Neighborhood       4808.825008
# Condition1       -10863.422868
# Condition2       -79089.575930
# BldgType          -6760.437040
# RoofStyle          6029.216545
# RoofMatl          15354.921528
# Exterior1st      -17812.505574
# Exterior2nd       12099.392811
# MasVnrType        15376.979537
# ExterQual        -30352.932265
# Foundation        11805.638340
# BsmtQual         -14547.317628
# BsmtCond           4031.143064
# BsmtExposure      -7465.440101
# HeatingQC         -2624.159254
# Electrical        -2118.263782
# KitchenQual      -20902.506777
# Functional        23948.169480
# FireplaceQu       -7731.143673
# GarageType         9530.774596
# GarageFinish      -3399.762819
# ...

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     164.9
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        11:41:33   Log-Likelihood:                -16796.
# No. Observations:                1447   AIC:                         3.372e+04
# Df Residuals:                    1383   BIC:                         3.406e+04
# Df Model:                          63
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.799e+05    715.352    251.516      0.000    1.79e+05    1.81e+05
# ...

# %%
St_X3=St_X2.drop(['MSZoning','LandContour','Fence','OpenPorchSF','BsmtUnfSF'],axis=1)

# %%
X_train_sm = St_X3
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(Y,X_train_sm).fit()
print(type(lm_1))
# print the coefficients
lm_1.params
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
# D:\AnacondaPython\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# const            179922.475466
# Street            34741.054586
# Alley              6084.286189
# LotShape          -1180.605722
# Utilities        -50322.358812
# Neighborhood       5054.279019
# Condition1       -11172.980417
# Condition2       -80430.108648
# BldgType          -6782.185506
# RoofStyle          6144.247650
# RoofMatl          15413.690959
# Exterior1st      -17560.114539
# Exterior2nd       11838.197207
# MasVnrType        15431.352619
# ExterQual        -30513.680499
# Foundation        11398.241999
# BsmtQual         -14482.218551
# BsmtCond           3788.037666
# BsmtExposure      -7405.821996
# HeatingQC         -2827.989803
# Electrical        -2171.615393
# ...

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     176.4
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:05:21   Log-Likelihood:                -16797.
# No. Observations:                1447   AIC:                         3.371e+04
# Df Residuals:                    1387   BIC:                         3.403e+04
# Df Model:                          59
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.799e+05    714.713    251.741      0.000    1.79e+05    1.81e+05
# ...

# %% [markdown]
# # VIF

# %%
ho_Data_up = ho_Data_up.apply(normalize)

# %%
ho_Data_up.drop(['HouseStyle','LowQualFinSF','HalfBath','LandSlope','LotConfig','BsmtFinType1','CentralAir','BsmtHalfBath'],axis=1,inplace=True)
ho_Data_up.drop(['MiscVal','ExterCond','BsmtFinType2','Heating','FullBath'],axis=1,inplace=True)
ho_Data_up.drop(['MSZoning','LandContour','Fence','OpenPorchSF','BsmtUnfSF'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-b00a114a2f81> in <module>
# ----> 1 ho_Data_up.drop(['HouseStyle','LowQualFinSF','HalfBath','LandSlope','LotConfig','BsmtFinType1','CentralAir','BsmtHalfBath'],axis=1,inplace=True)
#       2 ho_Data_up.drop(['MiscVal','ExterCond','BsmtFinType2','Heating','FullBath'],axis=1,inplace=True)
#       3 ho_Data_up.drop(['MSZoning','LandContour','Fence','OpenPorchSF','BsmtUnfSF'],axis=1,inplace=True)
#
# D:\AnacondaPython\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
# ...

# %%
ho_Data_up.drop(['Id'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-417dbcfdff3e> in <module>
# ----> 1 ho_Data_up.drop(['Id'],axis=1,inplace=True)
#
# D:\AnacondaPython\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# D:\AnacondaPython\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
# UDF for calculating vif value
def vif_cal(input_data, dependent_col):
    vif_df = pd.DataFrame( columns = ['Var', 'Vif'])
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.OLS(y,x).fit().rsquared  
        vif=round(1/(1-rsq),2)
        vif_df.loc[i] = [xvar_names[i], vif]
    return vif_df.sort_values(by = 'Vif', axis=0, ascending=False, inplace=False)

# %%
vif_cal(input_data=ho_Data_up, dependent_col="SalePrice")
# Out:
#               Var     Vif
# 38      GrLivArea  128.97
# 57       2ndFlrSF   93.43
# 56       1stFlrSF   72.01
# 35      YearBuilt    6.04
# 44     GarageCars    5.85
# 58     GarageArea    5.53
# 42   TotRmsAbvGrd    5.18
# 28         PoolQC    5.04
# 49       PoolArea    4.86
# 32     MSSubClass    4.42
# 55    TotalBsmtSF    4.33
# 7        BldgType    4.06
# 11    Exterior2nd    4.01
# 10    Exterior1st    3.98
# 33    OverallQual    3.79
# 36   YearRemodAdd    2.68
# 13      ExterQual    2.58
# 40   BedroomAbvGr    2.56
# 54     BsmtFinSF1    2.55
# 15       BsmtQual    2.41
# 39   BsmtFullBath    2.04
# 14     Foundation    2.02
# 20    KitchenQual    2.01
# 26     GarageCond    1.94
# 25     GarageQual    1.94
# 23     GarageType    1.92
# 53     MasVnrArea    1.91
# 34    OverallCond    1.79
# 41   KitchenAbvGr    1.68
# 43     Fireplaces    1.64
# 24   GarageFinish    1.60
# 18      HeatingQC    1.59
# 12     MasVnrType    1.54
# 27     PavedDrive    1.47
# ...

# %%
St_X4=St_X3.drop(['1stFlrSF','2ndFlrSF','GrLivArea'],axis=1)

# %%
X_train_sm = St_X4
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(Y,X_train_sm).fit()
print(type(lm_1))
# print the coefficients
lm_1.params
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
# D:\AnacondaPython\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# const            179922.475466
# Street            39119.382872
# Alley             11754.892096
# LotShape          -1978.297286
# Utilities        -67635.799188
# Neighborhood       5406.579912
# Condition1       -13442.336033
# Condition2       -70830.027857
# BldgType         -13963.174506
# RoofStyle          3467.950808
# RoofMatl          30824.162157
# Exterior1st      -24307.975982
# Exterior2nd       16104.023004
# MasVnrType        14358.399259
# ExterQual        -30496.447924
# Foundation        22955.638299
# BsmtQual         -18224.255819
# BsmtCond           1422.977035
# BsmtExposure      -2218.418184
# HeatingQC         -4453.744335
# Electrical        -3627.437972
# ...

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     159.8
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:11:27   Log-Likelihood:                -16894.
# No. Observations:                1447   AIC:                         3.390e+04
# Df Residuals:                    1390   BIC:                         3.420e+04
# Df Model:                          56
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.799e+05    763.337    235.705      0.000    1.78e+05    1.81e+05
# ...

# %%
vif_cal(input_data=ho_Data_up.drop(['1stFlrSF','2ndFlrSF','GrLivArea'],axis=1), dependent_col="SalePrice")
# Out:
#               Var   Vif
# 43     GarageCars  5.82
# 35      YearBuilt  5.73
# 55     GarageArea  5.43
# 28         PoolQC  4.89
# 48       PoolArea  4.77
# 11    Exterior2nd  4.00
# 10    Exterior1st  3.95
# 7        BldgType  3.71
# 32     MSSubClass  3.67
# 33    OverallQual  3.63
# 41   TotRmsAbvGrd  3.54
# 54    TotalBsmtSF  2.67
# 36   YearRemodAdd  2.66
# 13      ExterQual  2.56
# 53     BsmtFinSF1  2.53
# 39   BedroomAbvGr  2.48
# 15       BsmtQual  2.39
# 38   BsmtFullBath  2.03
# 20    KitchenQual  2.00
# 14     Foundation  1.97
# 26     GarageCond  1.94
# 25     GarageQual  1.94
# 23     GarageType  1.90
# 52     MasVnrArea  1.87
# 34    OverallCond  1.78
# 24   GarageFinish  1.59
# 18      HeatingQC  1.59
# 40   KitchenAbvGr  1.57
# 42     Fireplaces  1.55
# 12     MasVnrType  1.53
# 27     PavedDrive  1.46
# 51        LotArea  1.42
# 17   BsmtExposure  1.40
# 45  EnclosedPorch  1.33
# 19     Electrical  1.32
# 44     WoodDeckSF  1.28
# 37     BsmtFinSF2  1.24
# ...

# %%
St_X6=St_X5.drop(['PoolQC','PoolArea'],axis=1)

# %%
X_train_sm = St_X6
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(Y,X_train_sm).fit()
print(type(lm_1))
# print the coefficients
lm_1.params
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
# D:\AnacondaPython\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# const            179922.475466
# Street            38527.220667
# Neighborhood      10381.790551
# BldgType          -9885.741753
# RoofStyle         17385.960185
# RoofMatl          40273.420061
# MasVnrType        19113.950128
# Foundation        28631.905588
# BsmtExposure      -9264.124664
# HeatingQC         -6501.468344
# KitchenQual      -43159.520562
# Functional        16207.331814
# FireplaceQu       -9106.946037
# SaleCondition     17099.971618
# OverallCond       49635.801829
# YearBuilt         51396.443520
# FullBath          33989.654243
# BedroomAbvGr     -87208.384615
# KitchenAbvGr     -84673.077669
# TotRmsAbvGrd     129457.308084
# WoodDeckSF        18864.897333
# ...

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     271.0
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        10:31:17   Log-Likelihood:                -17008.
# No. Observations:                1447   AIC:                         3.407e+04
# Df Residuals:                    1418   BIC:                         3.423e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.799e+05    817.865    219.990      0.000    1.78e+05    1.82e+05
# ...

# %%
vif_cal(input_data=ho_Data_up.drop(['1stFlrSF','PoolQC','PoolArea'],axis=1), dependent_col="SalePrice")
# Out:
#               Var   Vif
# 18   TotRmsAbvGrd  3.92
# 14      YearBuilt  3.52
# 26       2ndFlrSF  2.68
# 25    TotalBsmtSF  2.61
# 16   BedroomAbvGr  2.35
# 15       FullBath  2.26
# 6      Foundation  1.86
# 23     MasVnrArea  1.78
# 27     GarageArea  1.78
# 9     KitchenQual  1.58
# 24     BsmtFinSF1  1.46
# 5      MasVnrType  1.45
# 8       HeatingQC  1.44
# 17   KitchenAbvGr  1.44
# 2        BldgType  1.42
# 13    OverallCond  1.32
# 22        LotArea  1.32
# 7    BsmtExposure  1.28
# 20  EnclosedPorch  1.26
# 19     WoodDeckSF  1.21
# 3       RoofStyle  1.17
# 11    FireplaceQu  1.15
# 1    Neighborhood  1.11
# 0          Street  1.11
# 10     Functional  1.10
# 12  SaleCondition  1.09
# 21    ScreenPorch  1.08
# 4        RoofMatl  1.08

# %%
St_X7=St_X6.drop(['TotRmsAbvGrd','YearBuilt','2ndFlrSF','TotalBsmtSF'],axis=1)

# %%
X_train_sm = St_X7
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(Y,X_train_sm).fit()
print(type(lm_1))
# print the coefficients
lm_1.params
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
# D:\AnacondaPython\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# const            179922.475466
# Street            62172.743021
# Neighborhood      10433.309535
# BldgType         -10919.749290
# RoofStyle         29208.012271
# RoofMatl          51755.371067
# MasVnrType        22537.196527
# Foundation        35119.729447
# BsmtExposure     -16900.573146
# HeatingQC        -16931.836007
# KitchenQual      -65551.268800
# Functional        19445.584876
# FireplaceQu       -7416.909101
# SaleCondition     20555.468894
# OverallCond       25937.096827
# FullBath          99873.744869
# BedroomAbvGr      60212.748977
# KitchenAbvGr     -79701.593144
# WoodDeckSF        36801.461231
# EnclosedPorch     11927.288285
# ScreenPorch       49883.170494
# ...

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     199.3
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        10:37:06   Log-Likelihood:                -17280.
# No. Observations:                1447   AIC:                         3.461e+04
# Df Residuals:                    1422   BIC:                         3.474e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.799e+05    985.338    182.600      0.000    1.78e+05    1.82e+05
# ...

# %%
vif_cal(input_data=ho_Data_up.drop(['1stFlrSF','PoolQC','PoolArea','TotRmsAbvGrd','YearBuilt','2ndFlrSF','TotalBsmtSF'],axis=1), dependent_col="SalePrice")
# Out:
#               Var   Vif
# 14       FullBath  1.87
# 21     MasVnrArea  1.70
# 23     GarageArea  1.60
# 6      Foundation  1.49
# 15   BedroomAbvGr  1.49
# 9     KitchenQual  1.49
# 5      MasVnrType  1.43
# 8       HeatingQC  1.37
# 2        BldgType  1.34
# 20        LotArea  1.31
# 22     BsmtFinSF1  1.29
# 7    BsmtExposure  1.22
# 16   KitchenAbvGr  1.20
# 17     WoodDeckSF  1.20
# 13    OverallCond  1.18
# 11    FireplaceQu  1.12
# 3       RoofStyle  1.12
# 1    Neighborhood  1.11
# 0          Street  1.10
# 18  EnclosedPorch  1.10
# 12  SaleCondition  1.09
# 4        RoofMatl  1.08
# 19    ScreenPorch  1.06
# 10     Functional  1.06

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(St_X4,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(lm.intercept_)
# Out:
# 179922.47546648243

# %%
print(lm.coef_)
# Out:
# [ 3.91193829e+04  1.17548921e+04 -1.97829729e+03 -6.76357992e+04
#   5.40657991e+03 -1.34423360e+04 -7.08300279e+04 -1.39631745e+04
#   3.46795081e+03  3.08241622e+04 -2.43079760e+04  1.61040230e+04
#   1.43583993e+04 -3.04964479e+04  2.29556383e+04 -1.82242558e+04
#   1.42297704e+03 -2.21841818e+03 -4.45374433e+03 -3.62743797e+03
#  -2.32166445e+04  1.60775622e+04 -3.34042741e+03  9.39805348e+03
#  -4.62271510e+03 -1.01400329e+04  7.96755807e+03  5.00625448e+03
#   8.86046716e+04 -1.16167157e+04 -7.34269168e+03  1.65950578e+04
#   1.78693985e+03  1.10257480e+05  3.57165061e+04  1.91175924e+04
#   7.14961956e+03  2.05443782e+04  7.20331253e+01 -1.62891247e+04
#  -5.50067473e+04  1.34644393e+05  2.52142020e+04  1.42224135e+04
#   2.03769209e+04  1.33004755e+04  1.80873241e+04  2.77240201e+04
#   6.93926232e+04 -2.65218375e+03 -3.17569150e+03  1.15447888e+05
#   7.16121206e+04  4.86358803e+04  6.77466744e+04  4.01170341e+04]

# %% [markdown]
# # Prediction with test data

# %%
ho_Data_test=pd.read_csv('test.csv')

# %%
ho_Data_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
ho_Data_test.drop(['GarageYrBlt'],axis=1,inplace=True)
ho_Data_test.drop(['LotFrontage'],axis=1,inplace=True)
ho_Data_test.drop(['HouseStyle','LowQualFinSF','HalfBath','LandSlope','LotConfig','BsmtFinType1','CentralAir','BsmtHalfBath'],axis=1,inplace=True)
ho_Data_test.drop(['MiscVal','ExterCond','BsmtFinType2','Heating','FullBath'],axis=1,inplace=True)
ho_Data_test.drop(['MSZoning','LandContour','Fence','OpenPorchSF','BsmtUnfSF'],axis=1,inplace=True)

# %%
ho_Data_test.drop(['1stFlrSF','2ndFlrSF','GrLivArea'],axis=1,inplace=True)

# %%
ho_Data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# Utilities        1457 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# RoofMatl         1459 non-null object
# Exterior1st      1458 non-null object
# Exterior2nd      1458 non-null object
# MasVnrType       1443 non-null object
# MasVnrArea       1444 non-null float64
# ExterQual        1459 non-null object
# ...

# %%
ho_Data_test_categorical = ho_Data_test.select_dtypes(include=['object'])
ho_Data_test_noncategorical = ho_Data_test.select_dtypes(exclude=['object'])
#ho_Data_categorical=ho_Data_categorical.fillna('NoVal')

# %%
ho_Data_test_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 32 columns):
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# Utilities        1457 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# RoofStyle        1459 non-null object
# RoofMatl         1459 non-null object
# Exterior1st      1458 non-null object
# Exterior2nd      1458 non-null object
# MasVnrType       1443 non-null object
# ExterQual        1459 non-null object
# Foundation       1459 non-null object
# BsmtQual         1415 non-null object
# BsmtCond         1414 non-null object
# BsmtExposure     1415 non-null object
# HeatingQC        1459 non-null object
# Electrical       1459 non-null object
# KitchenQual      1458 non-null object
# Functional       1457 non-null object
# ...

# %%
ho_Data_test_noncategorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 25 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# LotArea          1459 non-null int64
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# MasVnrArea       1444 non-null float64
# BsmtFinSF1       1458 non-null float64
# BsmtFinSF2       1458 non-null float64
# TotalBsmtSF      1458 non-null float64
# BsmtFullBath     1457 non-null float64
# BedroomAbvGr     1459 non-null int64
# KitchenAbvGr     1459 non-null int64
# TotRmsAbvGrd     1459 non-null int64
# Fireplaces       1459 non-null int64
# GarageCars       1458 non-null float64
# GarageArea       1458 non-null float64
# WoodDeckSF       1459 non-null int64
# EnclosedPorch    1459 non-null int64
# 3SsnPorch        1459 non-null int64
# ScreenPorch      1459 non-null int64
# ...

# %%
ho_Data_test_categorical=ho_Data_test_categorical.fillna('NoVal')

# %%
ho_Data_test_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 32 columns):
# Street           1459 non-null object
# Alley            1459 non-null object
# LotShape         1459 non-null object
# Utilities        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# RoofStyle        1459 non-null object
# RoofMatl         1459 non-null object
# Exterior1st      1459 non-null object
# Exterior2nd      1459 non-null object
# MasVnrType       1459 non-null object
# ExterQual        1459 non-null object
# Foundation       1459 non-null object
# BsmtQual         1459 non-null object
# BsmtCond         1459 non-null object
# BsmtExposure     1459 non-null object
# HeatingQC        1459 non-null object
# Electrical       1459 non-null object
# KitchenQual      1459 non-null object
# Functional       1459 non-null object
# ...

# %%
le_test = preprocessing.LabelEncoder()
ho_Data_test_categorical = ho_Data_test_categorical.apply(le_test.fit_transform)
ho_Data_test_categorical.head()
# Out:
#    Street  Alley  LotShape  Utilities  Neighborhood  Condition1  Condition2  \
# 0       1      1         3          0            12           1           2
# 1       1      1         0          0            12           2           2
# 2       1      1         0          0             8           2           2
# 3       1      1         0          0             8           2           2
# 4       1      1         0          0            22           2           2
#
#    BldgType  RoofStyle  RoofMatl  ...  FireplaceQu  GarageType  GarageFinish  \
# 0         0          1         0  ...            3           1             3
# 1         0          3         0  ...            3           1             3
# 2         0          1         0  ...            5           1             0
# 3         0          1         0  ...            2           1             0
# 4         4          1         0  ...            3           1             2
#
# ...

# %%
pd.isnull(ho_Data_test_noncategorical).sum()
# Out:
# Id               0
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# TotalBsmtSF      0
# BsmtFullBath     0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
ho_Data_test_noncategorical.describe()
# Out:
#                 Id   MSSubClass       LotArea  OverallQual  OverallCond  \
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean   2190.000000    57.378341   9819.161069     6.078821     5.553804
# std     421.321334    42.746880   4955.517327     1.436812     1.113740
# min    1461.000000    20.000000   1470.000000     1.000000     1.000000
# 25%    1825.500000    20.000000   7391.000000     5.000000     5.000000
# 50%    2190.000000    50.000000   9399.000000     6.000000     5.000000
# 75%    2554.500000    70.000000  11517.500000     7.000000     6.000000
# max    2919.000000   190.000000  56600.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1459.000000   1459.000000  1444.000000  1458.000000  1458.000000  ...
# mean   1971.357779   1983.662783   100.709141   439.203704    52.619342  ...
# std      30.390071     21.130467   177.625900   455.268042   176.753926  ...
# ...

# %%
(ho_Data_test_noncategorical.describe()).to_csv('Describe_toread.csv')

# %%
for i in range(0,ho_Data_test_noncategorical.shape[0]):
               if(np.isnan(ho_Data_test_noncategorical.iloc[i,7])):
                  ho_Data_test_noncategorical.iloc[i,7]=100.71
# Out:
# D:\AnacondaPython\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in range(0,ho_Data_test_noncategorical.shape[0]):
               if(np.isnan(ho_Data_test_noncategorical.iloc[i,8])):
                  ho_Data_test_noncategorical.iloc[i,8]=439.20

# %%
for i in range(0,ho_Data_test_noncategorical.shape[0]):
               if(np.isnan(ho_Data_test_noncategorical.iloc[i,9])):
                  ho_Data_test_noncategorical.iloc[i,9]=52.62

# %%
for i in range(0,ho_Data_test_noncategorical.shape[0]):
               if(np.isnan(ho_Data_test_noncategorical.iloc[i,10])):
                  ho_Data_test_noncategorical.iloc[i,10]=1046.12

# %%
for i in range(0,ho_Data_test_noncategorical.shape[0]):
               if(np.isnan(ho_Data_test_noncategorical.iloc[i,11])):
                  ho_Data_test_noncategorical.iloc[i,11]=1156.53

# %%
for i in range(0,ho_Data_test_noncategorical.shape[0]):
               if(np.isnan(ho_Data_test_noncategorical.iloc[i,16])):
                  ho_Data_test_noncategorical.iloc[i,16]=1.77

# %%
for i in range(0,ho_Data_test_noncategorical.shape[0]):
               if(np.isnan(ho_Data_test_noncategorical.iloc[i,17])):
                  ho_Data_test_noncategorical.iloc[i,17]=472.77

# %%
ho_Data_test_noncategorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 25 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# LotArea          1459 non-null int64
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# MasVnrArea       1459 non-null float64
# BsmtFinSF1       1459 non-null float64
# BsmtFinSF2       1459 non-null float64
# TotalBsmtSF      1459 non-null float64
# BsmtFullBath     1459 non-null float64
# BedroomAbvGr     1459 non-null int64
# KitchenAbvGr     1459 non-null int64
# TotRmsAbvGrd     1459 non-null int64
# Fireplaces       1459 non-null int64
# GarageCars       1459 non-null float64
# GarageArea       1459 non-null float64
# WoodDeckSF       1459 non-null int64
# EnclosedPorch    1459 non-null int64
# 3SsnPorch        1459 non-null int64
# ScreenPorch      1459 non-null int64
# ...

# %%
ho_Data_test_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 32 columns):
# Street           1459 non-null int32
# Alley            1459 non-null int32
# LotShape         1459 non-null int32
# Utilities        1459 non-null int32
# Neighborhood     1459 non-null int32
# Condition1       1459 non-null int32
# Condition2       1459 non-null int32
# BldgType         1459 non-null int32
# RoofStyle        1459 non-null int32
# RoofMatl         1459 non-null int32
# Exterior1st      1459 non-null int32
# Exterior2nd      1459 non-null int32
# MasVnrType       1459 non-null int32
# ExterQual        1459 non-null int32
# Foundation       1459 non-null int32
# BsmtQual         1459 non-null int32
# BsmtCond         1459 non-null int32
# BsmtExposure     1459 non-null int32
# HeatingQC        1459 non-null int32
# Electrical       1459 non-null int32
# KitchenQual      1459 non-null int32
# Functional       1459 non-null int32
# ...

# %%
ho_Data_test_up=pd.concat([ho_Data_test_noncategorical, ho_Data_test_categorical], axis=1)

# %%
ho_Data_test_up.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# LotArea          1459 non-null int64
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# MasVnrArea       1459 non-null float64
# BsmtFinSF1       1459 non-null float64
# BsmtFinSF2       1459 non-null float64
# TotalBsmtSF      1459 non-null float64
# BsmtFullBath     1459 non-null float64
# BedroomAbvGr     1459 non-null int64
# KitchenAbvGr     1459 non-null int64
# TotRmsAbvGrd     1459 non-null int64
# Fireplaces       1459 non-null int64
# GarageCars       1459 non-null float64
# GarageArea       1459 non-null float64
# WoodDeckSF       1459 non-null int64
# EnclosedPorch    1459 non-null int64
# 3SsnPorch        1459 non-null int64
# ScreenPorch      1459 non-null int64
# ...

# %%
ho_Data_test_up_id=ho_Data_test_up['Id']

# %%
ho_Data_test_up.drop(['Id'],axis=1,inplace=True)

# %%
#St_ho_Data_test_up=(ho_Data_test_up-ho_Data_test_up.mean())/ho_Data_test_up.std()
St_ho_Data_test_up=ho_Data_test_up.apply(normalize)

# %%
St_ho_Data_test_up.head()
# Out:
#    MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   -0.219873  0.032702    -0.119869     0.055775  -0.079067     -0.377713
# 1   -0.219873  0.080679    -0.008758     0.055775  -0.101968     -0.427713
# 2    0.015422  0.072752    -0.119869    -0.069225   0.195742      0.238954
# 3    0.015422  0.002881    -0.008758     0.055775   0.203376      0.238954
# 4    0.368363 -0.087324     0.213464    -0.069225   0.157574      0.138954
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  TotalBsmtSF  ...  FireplaceQu  \
# 0   -0.078069    0.007181    0.059882    -0.032212  ...    -0.011103
# 1    0.005652    0.120647   -0.034482     0.055521  ...    -0.011103
# 2   -0.078069    0.087730   -0.034482    -0.023183  ...     0.388897
# 3   -0.062565    0.040598   -0.034482    -0.023576  ...    -0.211103
# 4   -0.078069   -0.043941   -0.034482     0.045904  ...    -0.011103
#
#    GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive    PoolQC  \
# ...

# %%
y_pred = lm.predict(St_ho_Data_test_up)

# %%
y_pred
# Out:
# array([262226.09692887, 227508.68465391, 189220.86127519, ...,
#        206268.96330328, 181054.2175109 ,  40298.97235218])

# %%
y_pred=pd.DataFrame(y_pred)

# %%
submission=pd.concat([ho_Data_test_up_id, y_pred], axis=1)

# %%
submission
# Out:
#         Id              0
# 0     1461  262226.096929
# 1     1462  227508.684654
# 2     1463  189220.861275
# 3     1464  130252.627665
# 4     1465  249873.024218
# 5     1466  165213.394961
# 6     1467  144049.863821
# 7     1468  176042.398353
# 8     1469  156855.308764
# 9     1470  191053.250774
# 10    1471  171581.044547
# 11    1472  173375.010570
# 12    1473  242073.981441
# 13    1474  287983.692857
# 14    1475  266566.018253
# 15    1476  131493.023559
# 16    1477  183396.463535
# 17    1478  133037.654456
# 18    1479  168654.563786
# 19    1480   30117.862374
# 20    1481   92309.263940
# 21    1482  212270.091566
# 22    1483  142917.223161
# 23    1484   48050.945543
# 24    1485  155911.123503
# 25    1486  154829.436002
# 26    1487  181786.650627
# 27    1488  256606.770783
# 28    1489  229281.043194
# 29    1490  190899.047975
# ...    ...            ...
# 1429  2890  107908.171102
# 1430  2891  222393.363860
# 1431  2892  153046.262462
# ...

# %%
submission.to_csv('submission.csv')
