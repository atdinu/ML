# %%
import pandas as pd
import numpy as np
import re

# %%
ti_inp=pd.read_csv("train.csv")

# %%
ti_inp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
ti_inp.drop(['Embarked'],axis=1,inplace=True)
ti_inp.drop(['Cabin'],axis=1,inplace=True)
ti_inp.drop(['Ticket'],axis=1,inplace=True)

# %%
list(ti_inp.columns.values)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Fare']

# %%
ti_inp1=ti_inp[['Name','Age']]

# %%
ti_inp.shape[1]
# Out:
# 9

# %%
ar=ti_inp.iloc[881,3].split()

# %%
ti_inp.iloc[881,0:8]
# Out:
# PassengerId                   882
# Survived                        0
# Pclass                          3
# Name           Markun, Mr. Johann
# Sex                          male
# Age                            33
# SibSp                           0
# Parch                           0
# Name: 881, dtype: object

# %%
print(ar)
# Out:
# ['Markun,', 'Mr.', 'Johann']

# %%
Male=[]
Female=[]
Girl=[]
Boy=[]
Restofit=[]
for i in range(0,ti_inp.shape[0]):
    name_ar=set(ti_inp.iloc[i,3].split())
   # for name in name_ar:
    if('Mr.' in name_ar):
        Male.append([ti_inp.iloc[i,0],ti_inp.iloc[i,1],ti_inp.iloc[i,2],ti_inp.iloc[i,3],ti_inp.iloc[i,4],ti_inp.iloc[i,5],ti_inp.iloc[i,6],ti_inp.iloc[i,7],ti_inp.iloc[i,8]])
    elif('Mrs.' in name_ar):
        Female.append([ti_inp.iloc[i,0],ti_inp.iloc[i,1],ti_inp.iloc[i,2],ti_inp.iloc[i,3],ti_inp.iloc[i,4],ti_inp.iloc[i,5],ti_inp.iloc[i,6],ti_inp.iloc[i,7],ti_inp.iloc[i,8]])
    elif('Miss.' in name_ar):
        Girl.append([ti_inp.iloc[i,0],ti_inp.iloc[i,1],ti_inp.iloc[i,2],ti_inp.iloc[i,3],ti_inp.iloc[i,4],ti_inp.iloc[i,5],ti_inp.iloc[i,6],ti_inp.iloc[i,7],ti_inp.iloc[i,8]])
    elif('Master.' in name_ar):
        Boy.append([ti_inp.iloc[i,0],ti_inp.iloc[i,1],ti_inp.iloc[i,2],ti_inp.iloc[i,3],ti_inp.iloc[i,4],ti_inp.iloc[i,5],ti_inp.iloc[i,6],ti_inp.iloc[i,7],ti_inp.iloc[i,8]])
    else:
        Restofit.append([ti_inp.iloc[i,0],ti_inp.iloc[i,1],ti_inp.iloc[i,2],ti_inp.iloc[i,3],ti_inp.iloc[i,4],ti_inp.iloc[i,5],ti_inp.iloc[i,6],ti_inp.iloc[i,7],ti_inp.iloc[i,8]])

# %%
Male_df=pd.DataFrame(Male, columns=['PassengerId','Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Female_df=pd.DataFrame(Female, columns=['PassengerId','Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Girl_df=pd.DataFrame(Girl, columns=['PassengerId','Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Boy_df=pd.DataFrame(Boy, columns=['PassengerId','Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Restofit_df=pd.DataFrame(Restofit, columns=['PassengerId','Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])

# %%
Female_df['Age'].mean()
# Out:
# 35.898148148148145

# %%
Girl_df['Age'].mean()
# Out:
# 21.773972602739725

# %%
Boy_df['Age'].mean()
# Out:
# 4.574166666666667

# %%
Girl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 9 columns):
# PassengerId    182 non-null int64
# Survived       182 non-null int64
# Pclass         182 non-null int64
# Name           182 non-null object
# Sex            182 non-null object
# Age            146 non-null float64
# SibSp          182 non-null int64
# Parch          182 non-null int64
# Fare           182 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 12.9+ KB

# %%
for i in range(0,Male_df.shape[0]):
               if(np.isnan(Male_df.iloc[i,5])):
                  Male_df.iloc[i,5]=32.36

# %%
for i in range(0,Female_df.shape[0]):
               if(np.isnan(Female_df.iloc[i,5])):
                  Female_df.iloc[i,5]=35.89

# %%
for i in range(0,Girl_df.shape[0]):
               if(np.isnan(Girl_df.iloc[i,5])):
                  Girl_df.iloc[i,5]=21.77

# %%
for i in range(0,Boy_df.shape[0]):
               if(np.isnan(Boy_df.iloc[i,5])):
                  Boy_df.iloc[i,5]=4.57

# %%
Boy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
# PassengerId    40 non-null int64
# Survived       40 non-null int64
# Pclass         40 non-null int64
# Name           40 non-null object
# Sex            40 non-null object
# Age            40 non-null float64
# SibSp          40 non-null int64
# Parch          40 non-null int64
# Fare           40 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.9+ KB

# %%
Restofit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
# PassengerId    27 non-null int64
# Survived       27 non-null int64
# Pclass         27 non-null int64
# Name           27 non-null object
# Sex            27 non-null object
# Age            26 non-null float64
# SibSp          27 non-null int64
# Parch          27 non-null int64
# Fare           27 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.0+ KB

# %%
Restofit_df=Restofit_df[~np.isnan(Restofit_df['Age'])]

# %%
df_impu=((Male_df.append(Female_df)).append(Girl_df)).append(Boy_df)

# %%
df_impu
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             5         0       3
# 2             6         0       3
# 3             7         0       1
# 4            13         0       3
# 5            14         0       3
# 6            18         1       2
# 7            21         0       2
# 8            22         1       2
# 9            24         1       1
# 10           27         0       3
# 11           28         0       1
# 12           30         0       3
# 13           34         0       2
# 14           35         0       1
# 15           36         0       1
# 16           37         1       3
# 17           38         0       3
# 18           43         0       3
# 19           46         0       3
# 20           47         0       3
# 21           49         0       3
# 22           52         0       3
# 23           55         0       1
# 24           56         1       1
# 25           58         0       3
# ...

# %%
df_final=df_impu.append(Restofit_df)

# %%
df_final
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             5         0       3
# 2             6         0       3
# 3             7         0       1
# 4            13         0       3
# 5            14         0       3
# 6            18         1       2
# 7            21         0       2
# 8            22         1       2
# 9            24         1       1
# 10           27         0       3
# 11           28         0       1
# 12           30         0       3
# 13           34         0       2
# 14           35         0       1
# 15           36         0       1
# 16           37         1       3
# 17           38         0       3
# 18           43         0       3
# 19           46         0       3
# 20           47         0       3
# 21           49         0       3
# 22           52         0       3
# 23           55         0       1
# 24           56         1       1
# 25           58         0       3
# ...

# %%
df_final.drop(['Name'],axis=1,inplace=True)

# %%
df_final['Sex'] = df_final['Sex'].map({'male': 1, 'female': 0})

# %%
Standa_df=df_final[['PassengerId','Pclass','Sex','Age','SibSp','Parch','Fare']]

# %%
Standa_df=(Standa_df-Standa_df.mean())/Standa_df.std()

# %%
Standa_df.head()
# Out:
#    PassengerId    Pclass      Sex       Age     SibSp     Parch      Fare
# 0    -1.728277  0.825829  0.73792 -0.582874  0.431829 -0.473733 -0.501720
# 1    -1.712730  0.825829  0.73792  0.396179 -0.474605 -0.473733 -0.485630
# 2    -1.708843  0.825829  0.73792  0.197356 -0.474605 -0.473733 -0.477418
# 3    -1.704956 -1.568268  0.73792  1.827103 -0.474605 -0.473733  0.395541
# 4    -1.681634  0.825829  0.73792 -0.733498 -0.474605 -0.473733 -0.485630

# %%
Sur_titdata=df_final['Survived']

# %%
Sur_titdata.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Survived, dtype: int64

# %%
Standa_df.drop(['PassengerId'],axis=1,inplace=True)

# %%
Standa_df.drop(['Parch'],axis=1,inplace=True)

# %%
Standa_df.drop(['Fare'],axis=1,inplace=True)

# %%
import statsmodels.api as sm
logm1 = sm.GLM(Sur_titdata,(sm.add_constant(Standa_df)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# D:\AnacondaPython\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  890
# Model:                            GLM   Df Residuals:                      885
# Model Family:                Binomial   Df Model:                            4
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -392.32
# Date:                Wed, 25 Sep 2019   Deviance:                       784.64
# Time:                        10:48:28   Pearson chi2:                     917.
# No. Iterations:                     5   Covariance Type:             nonrobust
# ...

# %%
tit_testdata=pd.read_csv("test.csv")

# %%
tit_testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
tit_testdata.drop(['Embarked'],axis=1,inplace=True)
tit_testdata.drop(['Cabin'],axis=1,inplace=True)
tit_testdata.drop(['Ticket'],axis=1,inplace=True)

# %%
Male=[]
Female=[]
Girl=[]
Boy=[]
Restofit=[]
for i in range(0,tit_testdata.shape[0]):
    name_ar=set(tit_testdata.iloc[i,2].split())
   # for name in name_ar:
    if('Mr.' in name_ar):
        Male.append([tit_testdata.iloc[i,0],tit_testdata.iloc[i,1],tit_testdata.iloc[i,2],tit_testdata.iloc[i,3],tit_testdata.iloc[i,4],tit_testdata.iloc[i,5],tit_testdata.iloc[i,6],tit_testdata.iloc[i,7]])
    elif('Mrs.' in name_ar):
        Female.append([tit_testdata.iloc[i,0],tit_testdata.iloc[i,1],tit_testdata.iloc[i,2],tit_testdata.iloc[i,3],tit_testdata.iloc[i,4],tit_testdata.iloc[i,5],tit_testdata.iloc[i,6],tit_testdata.iloc[i,7]])
    elif('Miss.' in name_ar):
        Girl.append([tit_testdata.iloc[i,0],tit_testdata.iloc[i,1],tit_testdata.iloc[i,2],tit_testdata.iloc[i,3],tit_testdata.iloc[i,4],tit_testdata.iloc[i,5],tit_testdata.iloc[i,6],tit_testdata.iloc[i,7]])
    elif('Master.' in name_ar):
        Boy.append([tit_testdata.iloc[i,0],tit_testdata.iloc[i,1],tit_testdata.iloc[i,2],tit_testdata.iloc[i,3],tit_testdata.iloc[i,4],tit_testdata.iloc[i,5],tit_testdata.iloc[i,6],tit_testdata.iloc[i,7]])
    else:
        Restofit.append([tit_testdata.iloc[i,0],tit_testdata.iloc[i,1],tit_testdata.iloc[i,2],tit_testdata.iloc[i,3],tit_testdata.iloc[i,4],tit_testdata.iloc[i,5],tit_testdata.iloc[i,6],tit_testdata.iloc[i,7]])

# %%
Male_df=pd.DataFrame(Male, columns=['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Female_df=pd.DataFrame(Female, columns=['PassengerId','Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Girl_df=pd.DataFrame(Girl, columns=['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Boy_df=pd.DataFrame(Boy, columns=['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])
Restofit_df=pd.DataFrame(Restofit, columns=['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'])

# %%
Male_df['Age'].mean()
# Out:
# 32.0

# %%
Female_df['Age'].mean()
# Out:
# 38.903225806451616

# %%
Girl_df['Age'].mean()
# Out:
# 21.774843750000002

# %%
Boy_df['Age'].mean()
# Out:
# 7.406470588235294

# %%
for i in range(0,Male_df.shape[0]):
               if(np.isnan(Male_df.iloc[i,4])):
                  Male_df.iloc[i,4]=32.0

# %%
for i in range(0,Female_df.shape[0]):
               if(np.isnan(Female_df.iloc[i,4])):
                  Female_df.iloc[i,4]=38.90

# %%
for i in range(0,Girl_df.shape[0]):
               if(np.isnan(Girl_df.iloc[i,4])):
                  Girl_df.iloc[i,4]=21.77

# %%
for i in range(0,Boy_df.shape[0]):
               if(np.isnan(Boy_df.iloc[i,4])):
                  Boy_df.iloc[i,4]=7.40

# %%
Male_df_nan=Male_df[np.isnan(Male_df['Fare'])]

# %%
Male_df_nan
# Out:
#     PassengerId  Pclass                Name   Sex   Age  SibSp  Parch  Fare
# 89         1044       3  Storey, Mr. Thomas  male  60.5      0      0   NaN

# %%
for i in range(0,Male_df.shape[0]):
               if(np.isnan(Male_df.iloc[i,7])):
                  Male_df.iloc[i,7]=35.63

# %%
Restofit_df_nan=Restofit_df[np.isnan(Restofit_df['Age'])]

# %%
Restofit_df_nan
# Out:
#    PassengerId  Pclass                     Name     Sex  Age  SibSp  Parch  \
# 0          980       3  O'Donoghue, Ms. Bridget  female  NaN      0      0
#
#    Fare
# 0  7.75

# %%
for i in range(0,Restofit_df.shape[0]):
               if(np.isnan(Restofit_df.iloc[i,4])):
                  Restofit_df.iloc[i,4]=38.90

# %%
Restofit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
# PassengerId    7 non-null int64
# Pclass         7 non-null int64
# Name           7 non-null object
# Sex            7 non-null object
# Age            7 non-null float64
# SibSp          7 non-null int64
# Parch          7 non-null int64
# Fare           7 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 528.0+ bytes

# %%
#Restofit_df=Restofit_df[~np.isnan(Restofit_df['Age'])]
#Male_df=Male_df[~np.isnan(Male_df['Fare'])]

# %%
df_impu=((Male_df.append(Female_df)).append(Girl_df)).append(Boy_df)

# %%
df_test_final=df_impu.append(Restofit_df)

# %%
df_test_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 6
# Data columns (total 8 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           418 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 29.4+ KB

# %%
df_test_final_bk=df_test_final.copy()
df_test_final_bk
# Out:
#     PassengerId  Pclass                                              Name  \
# 0           892       3                                  Kelly, Mr. James
# 1           894       2                         Myles, Mr. Thomas Francis
# 2           895       3                                  Wirz, Mr. Albert
# 3           897       3                        Svensson, Mr. Johan Cervin
# 4           899       2                      Caldwell, Mr. Albert Francis
# 5           901       3                           Davies, Mr. John Samuel
# 6           902       3                                  Ilieff, Mr. Ylio
# 7           903       1                        Jones, Mr. Charles Cresson
# 8           905       2                              Howard, Mr. Benjamin
# 9           908       2                                 Keane, Mr. Daniel
# 10          909       3                                 Assaf, Mr. Gerios
# 11          912       1                            Rothschild, Mr. Martin
# ...

# %%
df_test_final.drop(['PassengerId'],axis=1,inplace=True)
df_test_final.drop(['Parch'],axis=1,inplace=True)
df_test_final.drop(['Fare'],axis=1,inplace=True)

# %%
df_test_final_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 6
# Data columns (total 8 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           418 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 29.4+ KB

# %%
from sklearn import model_selection

# %%
seed = 7
kfold = model_selection.KFold(n_splits=5, random_state=seed)
model = LogisticRegression()
results = model_selection.cross_val_score(model, Standa_df, Sur_titdata, cv=kfold)
print(results)
# Out:
# [0.80898876 0.8258427  0.83707865 0.80337079 0.70224719]
# D:\AnacondaPython\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\AnacondaPython\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\AnacondaPython\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\AnacondaPython\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
df_test_final.drop(['Name'],axis=1,inplace=True)

# %%
df_test_final['Sex'] = df_test_final['Sex'].map({'male': 1, 'female': 0})

# %%
St_df_test_final=(df_test_final-df_test_final.mean())/df_test_final.std()

# %%
Surv_1=y_pred_df.iloc[:,[1]]
df_test_final_bk.reset_index(drop=True, inplace=True)
df_=pd.concat([df_test_final_bk,Surv_1],axis=1)
df_svm=pd.concat([df_test_final_bk,y_pred_svndf],axis=1)
df_svm_nonli=pd.concat([df_test_final_bk,y_pred_svndf_nonli],axis=1)

# %%
df_.rename(columns={ 1 : 'Survival_Prob'},inplace=True)
df_svm.rename(columns={ 1 : 'Survival_Prob_SVM'},inplace=True)
df_svm_nonli.rename(columns={ 1 : 'Survival_Prob_SVM_nonli'},inplace=True)

# %%
df_['Survival_Prob'] = df_.Survival_Prob.map( lambda x: 1 if x > 0.5 else 0)

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# PassengerId      418 non-null int64
# Pclass           418 non-null int64
# Name             418 non-null object
# Sex              418 non-null object
# Age              418 non-null float64
# SibSp            418 non-null int64
# Parch            418 non-null int64
# Fare             418 non-null float64
# Survival_Prob    418 non-null int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 29.5+ KB

# %%
df_svm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           418 non-null float64
# 0              418 non-null int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 29.5+ KB

# %%
df_svm_nonli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           418 non-null float64
# 0              418 non-null int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 29.5+ KB

# %%
df_submit=df_.drop(['Pclass','Sex','Age','SibSp','Parch','Fare'],axis=1)
df_submit_svm=df_svm.drop(['Pclass','Sex','Age','SibSp','Parch','Fare'],axis=1)
df_submit_svm_nonli=df_svm_nonli.drop(['Pclass','Sex','Age','SibSp','Parch','Fare'],axis=1)

# %%
df_submit
# Out:
#      PassengerId                                              Name  \
# 0            892                                  Kelly, Mr. James
# 1            894                         Myles, Mr. Thomas Francis
# 2            895                                  Wirz, Mr. Albert
# 3            897                        Svensson, Mr. Johan Cervin
# 4            899                      Caldwell, Mr. Albert Francis
# 5            901                           Davies, Mr. John Samuel
# 6            902                                  Ilieff, Mr. Ylio
# 7            903                        Jones, Mr. Charles Cresson
# 8            905                              Howard, Mr. Benjamin
# 9            908                                 Keane, Mr. Daniel
# 10           909                                 Assaf, Mr. Gerios
# 11           912                            Rothschild, Mr. Martin
# 12           915                   Williams, Mr. Richard Norris II
# ...

# %%
df_submit_svm
# Out:
#      PassengerId                                              Name  0
# 0            892                                  Kelly, Mr. James  0
# 1            894                         Myles, Mr. Thomas Francis  0
# 2            895                                  Wirz, Mr. Albert  0
# 3            897                        Svensson, Mr. Johan Cervin  0
# 4            899                      Caldwell, Mr. Albert Francis  0
# 5            901                           Davies, Mr. John Samuel  0
# 6            902                                  Ilieff, Mr. Ylio  0
# 7            903                        Jones, Mr. Charles Cresson  0
# 8            905                              Howard, Mr. Benjamin  0
# 9            908                                 Keane, Mr. Daniel  0
# 10           909                                 Assaf, Mr. Gerios  0
# 11           912                            Rothschild, Mr. Martin  0
# ...

# %%
df_submit_svm_nonli
# Out:
#      PassengerId                                              Name  0
# 0            892                                  Kelly, Mr. James  0
# 1            894                         Myles, Mr. Thomas Francis  0
# 2            895                                  Wirz, Mr. Albert  0
# 3            897                        Svensson, Mr. Johan Cervin  0
# 4            899                      Caldwell, Mr. Albert Francis  0
# 5            901                           Davies, Mr. John Samuel  0
# 6            902                                  Ilieff, Mr. Ylio  0
# 7            903                        Jones, Mr. Charles Cresson  0
# 8            905                              Howard, Mr. Benjamin  0
# 9            908                                 Keane, Mr. Daniel  0
# 10           909                                 Assaf, Mr. Gerios  0
# 11           912                            Rothschild, Mr. Martin  0
# ...

# %%
df_submit.drop(['Name'],axis=1,inplace=True)
df_submit.to_csv("Titanic_Survival_List.csv")
df_submit_svm.drop(['Name'],axis=1,inplace=True)
df_submit_svm.to_csv("Titanic_Survival_List_SVM.csv")
df_submit_svm_nonli.drop(['Name'],axis=1,inplace=True)
df_submit_svm_nonli.to_csv("Titanic_Survival_List_SVM_nonli.csv")
